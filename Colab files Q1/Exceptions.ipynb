# %% [markdown]
# # **Exceptions**

# %%
5/0
print("Hello")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-22e47580d256> in <module>()
# ----> 1 5/0
#       2 print("Hello")
#
# ZeroDivisionError: division by zero

# %%
try:
  a = int(input("Enter Number"))
  b = int(input("Enter Number"))
  c = a / b
  
except ZeroDivisionError:
  print("Please enter correct value")

except ValueError:
  print("Don't Leave Blank")
else:
  print(c)
# Out:
# Enter Number55
# Enter Number5
# 11.0

# %%
d = [1,2,3,4,5,6]
try:
  x = int(input("Enter Number"))
  y = int(input("Enter Number"))
  z = x/y
  e = d[5]
except:
  print("Error is caught")
else:
  print(z)
# Out:
# Enter Number5
# Enter Number5
# 1.0

# %%
d = []
try:
    x = int(input("Enter Number"))
    y = int(input("Enter Number"))
    z = x/y
    ee = d[5]

except Exception as e:
  print("Handle Error ==" +str(e))
else:
  print(z)
# Out:
# Enter Number5
# Enter Number5
# Handle Error ==list index out of range

# %%
d = []
try:
    x = int(input("Enter Number"))
    y = int(input("Enter Number"))
    z = x/y
    e = d[5]

except Exception as e:
  print("Handle Error ==" +str(e))
else:
    print(z)

finally:
  print("Finally will always run")
# Out:
# Enter Number55
# Enter Number5
# Handle Error ==list index out of range
# Finally will always run

# %%
class Student():
  def __init__(self,name,age):
    if age > 80 or age < 16:
      raise Exception("Age cannot be greater than 80 or less than 60")
    self.name = name
    self.age = age

# %%
age = int(input("Enter your age: "))
st = Student("Qausain", age)
print(st.age)
# Out:
# Enter your age: 55
# 55

# %%
try:
  age = int(input("Enter your age: "))
  st = Student("Qausain", age)
except Exception as h:
  print("Exception " + str(h))
else:
  print(st.age)
# Out:
# Enter your age:
# Exception invalid literal for int() with base 10: ''

# %%
class Student():
  def __init__(self,name,age):
    if age > 80 or age < 16:
      raise StudentAgeException("Age cannot be greater than 80 or less than 60")
    self.name = name
    self.age = age

class StudentAgeException(Exception):
  pass

# %%
age = int(input("Enter your age: "))
st = Student("Qausain", age)
print(st.age)

# %%
class Student():
  def __init__(self,name,age):
    if age > 80 or age < 16:
      raise StudentAgeException("Age cannot be greater than 80 or less than 60")
    self.name = name
    self.age = age

class StudentAgeException(Exception):
  pass

# %%
try:
  age = int(input("Enter your age: "))
  st = Student("Qausain", age)
except StudentAgeException as h:
  print("Exception " + str(h))
else:
  print(st.age)
# Out:
# Enter your age: 4
# Exception Age cannot be greater than 80 or less than 60

# %%
try:
  x = int(input("Enter Number"))
  y = int(input("Enter Number"))
  j = []
  z = x/y
except:
  print("Error is caught")
else:
  print(c)
# Out:
# Enter Number5
# Enter Number0
# Error is caught

# %%
x = int(input("Enter Number"))
y = int(input("Enter Number"))
d = []
try:
  z = x/y
  e = d[5]
except:
  print("Error is caught")
else:
  print(c)
# Out:
# Enter Number4
# Enter Number4
# Error is caught

# %%
25/5
# Out:
# 5.0
