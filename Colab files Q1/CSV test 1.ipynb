# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
! ls
# Out:
# drive  sample_data

# %%
cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
! ls

# %%
import csv
with open("First.csv") as f:
  contents = csv.reader(f)
  for content in contents:
    print(content)
# Out:
# ['Year', ' Event', ' Winner']
# ['1990', ' Birthday', ' Rehan']
# ['1992', ' Worldcup', ' Imran']
# ['1996', ' Atomic explosion', ' Musharaf ']

# %%
with open("absssc.csv", "w", newline="") as file:
  fileWriter = csv.writer(file)
  fileWriter.writerow(["2019", "CW2019", "ENG"])

# %%
with open("abc.csv", "r") as file:
  contents = csv.reader(file)
  for content in contents:
    print(content)
# Out:
# ['2019', 'CW2019', 'ENG']

# %%
with open("potions.csv", "r") as file:
  contents = csv.reader(file)
  for content in contents:
    print(content)
# Out:
# ['Potion', 'Effect', 'Telltale Property']
# ['Amortentia', 'Love', 'Steam']
# ['Confusing Concoction', 'Confusion', 'Nausea']
# ['Draught of Living Death', 'Sleep', 'Turns leaf to ashes']
# ['Draught of Peace', 'Comfort', 'None']
# ['Felix Felicis', 'Luck', 'Giddiness']
# ['Hiccoughing Potion', 'Stops hiccoughs', 'None']
# ['Pepperup Potion', 'Health', 'Steaming Ears']
# ['Polyjuice Potion', 'Shape shifting', 'Voice change']
# ['Skele-Gro', 'Bone growth', 'Disgusting taste']
# ["Sleekeazy's Hair Potion", 'Hair straightener', 'None']
# ['Veritaserum', 'Truth-telling', 'None']

# %%
import csv
with open("potions.csv") as file:
  abc = csv.reader(file)
  y = []
  for x in abc:
    y += x
    print(y)
# Out:
# ['Potion', 'Effect', 'Telltale Property']
# ['Potion', 'Effect', 'Telltale Property', 'Amortentia', 'Love', 'Steam']
# ['Potion', 'Effect', 'Telltale Property', 'Amortentia', 'Love', 'Steam', 'Confusing Concoction', 'Confusion', 'Nausea']
# ['Potion', 'Effect', 'Telltale Property', 'Amortentia', 'Love', 'Steam', 'Confusing Concoction', 'Confusion', 'Nausea', 'Draught of Living Death', 'Sleep', 'Turns leaf to ashes']
# ['Potion', 'Effect', 'Telltale Property', 'Amortentia', 'Love', 'Steam', 'Confusing Concoction', 'Confusion', 'Nausea', 'Draught of Living Death', 'Sleep', 'Turns leaf to ashes', 'Draught of Peace', 'Comfort', 'None']
# ['Potion', 'Effect', 'Telltale Property', 'Amortentia', 'Love', 'Steam', 'Confusing Concoction', 'Confusion', 'Nausea', 'Draught of Living Death', 'Sleep', 'Turns leaf to ashes', 'Draught of Peace', 'Comfort', 'None', 'Felix Felicis', 'Luck', 'Giddiness']
# ...

# %%
# For picking up information out of a csv file
target = drinks.index("vodka")

# %%
'''
#Exercises 11 and 12

If you have a spreadsheet program like Excel that exports to CSV, create a spreadsheet with at least three rows and three columns. 
Export it to the Desktop as a CSV file.

Alternatively, create a CSV file in IDLE—three lines of three comma-separated values each (no quotation marks, just text). 
Name the file whatever you like, but end it in .csv. Save it to the Desktop.

Revise the Python program you created in the previous set of exercises to read and display a value in this CSV file. Save the program and run it.
 
copyright © 2017 by Mark Myers. All rights reserved.
'''

# %%
import csv
with open("/content/drive/My Drive/Colab Notebooks/sample_csv.csv") as file:
  abc = csv.reader(file)
  for x in abc:
    print(x)
# Out:
# ['Description', 'Qty', 'Rate']
# ['mustard', '30', '115']
# ['black salt', '60', '29']

# %%
with open("abc.csv", "w", newline="") as xyz:
  data_h = csv.writer(xyz, delimiter=",")

# %%
with open("whatever.csv", "w", newline="") as f:
  data_handler = csv.writer(f, delimiter=",")
  data_handler.writerow(["Year", "Event", "Winner"])

# %%
with open("whatever.csv", "w", newline="") as f:
  writing_object = csv.writer(f, delimiter=",")
  writing_object.writerow(["Year", "Event", "Winner"])

# %%
with open("abc.csv", "a", newline="") as f:
  data_handler = csv.writer(f, delimiter=",")
  data_handler.writerow(["2018", "CW2018", "London"])

# %%
with open("abc.csv") as f:
  faaiz = csv.reader(f)
  rows = []
  for x in faaiz:
    rows += x
    print(x)
# Out:
# ['2019', 'CW2019', 'ENG']
# ['2018', 'CW2018', 'London']
