# %% [markdown]
# # **Function**

# %%
def add():
  print(12+5)

# %% [markdown]
# # **How to call Function**

# %%
add()
# Out:
# 17

# %% [markdown]
# # **Chapeter 41, Excercise 11**

# %%
# Turn this line of code into a function. Then call the function.

def display():
  print("Hello, World!")
display()
# Out:
# Hello, World!

# %% [markdown]
# # **Chapeter 41, Excercise 12**

# %%
# I've coded a dictionary. Code a function that loops through all the values of the dictionary and displays them.
# Call the function.

particulars = {
  "last name": "Verdi",
  "first name": "Giuseppe",
  "profession": "composer",
}
def loop():
  for a in particulars.values():
    print(a)
loop()
# Out:
# Verdi
# Giuseppe
# composer

# %% [markdown]
# # **Functions passing information posiotional arguments**

# %%
def abcd(): # parameter less function
  print("I am parameter less function")

# %%
abcd()
# Out:
# I am parameter less function

# %%
def addition(number1, number2): # parameterized function
  print(number1 + number2)

# %%
addition(45, 44)
# Out:
# 89

# %% [markdown]
# # **Chapeter 42, Exercise 11**
#
# You have to define a function before you can call it. But it'll be easier if you leave room at the top for the function definition and code the function call first. Then you can go back to the top and code the function.
# On line 9 call the function, passing the variables sales_total and tax_rate as arguments.
# Code the function. It calculates the tax on a sales total and displays a message.
# The function's two parameters are the total and the tax rate.
# Calculate the tax by multiplying the two parameters.
# Convert the result of the multiplication to a string.
# Display the concatenation of "The tax is " and the tax string.
# Click the Run button    above your code. If you've coded correctly, The tax is 3.0 will display in the right-hand panel

# %%
# Code the function starting on line 2, but code line 9 first.
def tax(ab, cd):
  a = sales_total * tax_rate
  b = str(a)
  print("The tax is " + b)
sales_total = 100
tax_rate = .03
# Start by coding the function call on line 9.
tax(sales_total, tax_rate)
# Out:
# The tax is 3.0

# %% [markdown]
# # **Chapeter 42, Excercise 12**
#
# On line 9 ask the user to enter a color and assign her answer to a variable.
# On line 15 call a function, passing it the name of the tuple I've coded and the name of the variable holding the user's color.
# Go to line 2 and code the function.
# The function loops through the tuple to see if the value of the variable is in it. If so, it displays a message and breaks the loop.
# Click the Run button    above your code. If you've coded correctly, the input query will display in the right-hand panel. If you enter one of the primary colors, your message will display. (You can click Instructions at the top of the right-hand panel to see the correct code.)

# %%
def color_check(primary_colors, color_entered):
  for a in primary_colors:
    if color_entered == a:
      print("Its a primary color.")
      break
  else:
    print("Sorry, Color not found")  
# Do this first.
# Ask the user to enter a color. Assign it to a variable.
color_entered = input("Enter a color to check:")
# Here's the tuple:
primary_colors = ("yellow", "red", "blue")
# Do this second.
# Call the function, passing the tuple name
# and the variable containing the user's color choice.
color_check(primary_colors, color_entered)
# Out:
# Enter a color to check:blala
# Sorry, Color not found

# %%
def color_check(primary_colors, color_entered):
  for a in primary_colors:
    if color_entered == a:
      print("Its a primary color.")
      break
  else:
    print("Sorry, Color not found") 
color_entered = input("Enter a color to check:")
primary_colors = ("yellow", "red", "blue")
color_check(primary_colors, color_entered)
# Out:
# Enter a color to check:edd
# Sorry, Color not found

# %% [markdown]
# # **Passing information keyword arguments**

# %%
# Sequence matters in positional arguments
def full_name(first, middle, last):
  print(first + middle + last)

# %%
full_name("Qausain ", "Manzoor ", "Erum")
# Out:
# Qausain Manzoor Erum

# %% [markdown]
# # **Keyword argument**

# %%
full_name(middle="Manzoor ", last="Erum", first="Qausain ")
# Out:
# Qausain Manzoor Erum

# %% [markdown]
# # **Default Value Argument**

# %%
def add1(number1 = 0, number2 = 0):
  print(number1 + number2)

# %%
add1(number2=5)
# Out:
# 5

# %% [markdown]
# # **Default Parameter**

# %%
def fulname_1(first, last, middle=" "):
  print(first + middle + last)

# %%
fulname_1("Qausain", "Manzoor")
# Out:
# Qausain Manzoor

# %% [markdown]
# # **Chapter 43, Notes**

# %%
def greet_user():
  """Display a simple greeting."""
  print("Hello!")
greet_user()
# Out:
# Hello!
# Hello, Jesse!

# %%
def greet_user(username):
  print("Hello, " + username.title() + "!")
greet_user('jesse')
# Out:
# Hello, Jesse!

# %%
def describe_pet(animal_type, pet_name):
# """Display information about a pet."""
  print("\nI have a " + animal_type + ".")
  print("My " + animal_type + "'s name is " + pet_name.upper() + ".")


describe_pet("chicken", "koko")
describe_pet('cow', 'resham')
describe_pet(pet_name='ducky bhai', animal_type='duck')
# Out:
# I have a chicken.
# My chicken's name is KOKO.
#
# I have a cow.
# My cow's name is RESHAM.
#
# I have a duck.
# My duck's name is DUCKY BHAI.

# %%
def describe_pet(pet_name, animal_type="dog"):
# """Display information about a pet."""
  print("\nI have a " + animal_type + ".")
  print("My " + animal_type + "'s name is " + pet_name.upper() + ".")

describe_pet(pet_name="tomy")
# Out:
# I have a dog.
# My dog's name is TOMY.

# %% [markdown]
# # **Chapeter 43, Exercise 11**
# Code a function that has two keyword parameters, first_name and last_name. The function displays the concatenation of first_name plus a string that's just a space plus last_name.
# Call the function, assigning your first and last names to the keywords.

# %%
def call_names(first_name, last_name):
  print(first_name + " " + last_name)
  
call_names(first_name="Qausain", last_name="Manzoor")
# Out:
# Qausain Manzoor

# %% [markdown]
# # **Chapeter 43, Exercise 12**
# 1- Begin by coding the function call on line 12. It has three keyword arguments. The values are the name of the dictionary, the name of one of the lists in the dictionary, and the index number of an element in the list. The function name and the keys are your choice.
#
# 2- Code the function starting on line 4. It targets the element within the list within the dictionary. Then it displays the targeted name.
#
# 3 - Click the Run button    above your code. If you've coded correctly, a name from one of the lists will display in the right-hand panel.

# %%
# First code the function call on line 12.
# Then come back and code the function starting on line 4.
# The function will take two or three lines, depending on how you approach it.
def calling_name(dict, list, index):
  target = (dict[list][index])
  print(target)
members = {
  "adults": ["Ditmar", "Salvador", "Punya"],
  "children": ["Caliban", "Eustis", "Ali"],
}
# First code the function call on line 12.
calling_name(dict=members, list="children",index=1)
# Out:
# Eustis

# %% [markdown]
# # **Chapeter 44, Exercise 11**
#
# Code a function that has two parameters, both of them numbers. Assign a default value to each parameter. The function does an arithmetic operation using the two numbers and displays the result.
# Call the function without passing arguments.
# Click the Run button    above your code. If you've coded correctly, the result of the arithmetic operation will display in the right-hand panel.

# %%
def add(ab = 100, cd = 200):
  ef = ab + cd
  print(ef)

add()
# Out:
# 300

# %% [markdown]
# # **Chapeter 44, Exercise 12**
#
# Run this code. See that it displays hammock: 12
# Revise the function call to make rug: 144 display.

# %%
products = ["hammock", "basket", "lounge", "rug"]
qtys = [12, 48, 60, 144]
def show_level(first_list = products, second_list = qtys, first_index = 3, second_index = 3):
  product = first_list[first_index]
  qty = str(second_list[second_index])
  info_to_show = product + ": " + qty
  print (info_to_show)
show_level()
# Out:
# rug: 144

# %% [markdown]
# # **Chapeter 45, Exercise 11**
#
# Code a function that does a math operation on two parameters and displays the result.
# Call the function. The first argument is a positional argument. The second argument is a keyword argument.

# %%
def math_operation(z, y):
  x = z + y
  print(x)
  
math_operation(40, y =50)
# Out:
# 90

# %% [markdown]
# # **Chapeter 45, Exercise 12**
# Code a function with two parameters that have defaults. The function displays the parameters on separate lines.
# Call the function, overriding both defaults.
# Click the Run button    above your code. If you've coded correctly, the values provided by the calling code arguments will display in the right-hand panel.

# %%
def dft(a = 10, b = 20):
  print(a + b)

dft(50, 40)
# Out:
# 90
