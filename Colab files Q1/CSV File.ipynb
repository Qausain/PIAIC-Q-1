# %% [markdown]
# # **CSV**
# Comma separated value

# %%
# import csv
# with open("abc.csv") as f:
# content_of_file = csv.reader(f)

# %%
# You have to loop through data of content_of_file, line by line, adding each line to a list.
# import csv
# with open("abc.csv") as f:
#   content_of_f = csv.reader(f)
#   potter_competition = []
#   for each_line in content_of_f:
#     potter_competition += each_line

# %%
# Writing to CSV file
# with open("whatever.csv", "w", newline="") as f:
# data_handler = csv.writer(f,delimiter=",")
# data_handler.writerow(["year", "event", "Winner")]
# data_handler.writerow(["1995", "best kept town", "none"])
# data_handler.writerow(["1992", "world-cup", "Imran Khan"])

# %%
# Appending to CSV file
# with open("whatever.csv", "a", newline="") as f:
# data_handler = csv.writer(f,delimiter=",")
# data_handler.writerow(["year", "event", "Winner")]
# data_handler.writerow(["1995", "best kept town", "none"])
# data_handler.writerow(["1992", "world-cup", "Imran Khan"])
