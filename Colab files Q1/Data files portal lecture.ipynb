# %%
with open("/content/drive/My Drive/Colab Notebooks/newdatafile.txt", "r") as file:
  content = file.read()
print(content)
# Out:
# Hello data files

# %%
pwd
# Out:
# '/content'

# %%
/content/drive/My Drive/Colab Notebooks/newdatafile.txt

# %%
drive.mount("/content/drive", force_remount=True)

with open("/content/drive/My Drive/Colab Notebooks/newdatafile.txt", "r") as file:
  content = file.read()
print(content)

# %%
with open("/content/drive/My Drive/Colab Notebooks/newdatafile.txt", "r") as file:
  content = file.read()
print(content)

# %%
with open("/content/drive/My Drive/Colab Notebooks/newdatafile.txt", "w") as qausain:
  abc = qausain.write("Hello data files")

# %%
with open("/content/drive/My Drive/Colab Notebooks/newdatafile.txt", "r") as qausain:
  xyz = qausain.read()
print(xyz)
# Out:
# Hello data filesTHis text is added via append mode in python. THis text is added via append mode in python

# %%
with open("/content/drive/My Drive/Colab Notebooks/nonexisting.txt", "w") as file:
  faaiz = file.write("This file created using w mode")

# %%
with open("/content/drive/My Drive/Colab Notebooks/nonexisting.txt", "r") as file:
  faaiz = file.read()
print(faaiz)
# Out:
# . This text is added via w+ mode

# %%
with open("/content/drive/My Drive/Colab Notebooks/newdatafile.txt", "a") as file:
  faaiz = file.write(". THis text is added via append mode in python")

# %%
with open("/content/drive/My Drive/Colab Notebooks/nonexisting.txt", "w+") as file:
  file.write(". This text is added via w+ mode")
  file.seek(0)
  print(file.read())
# Out:
# . This text is added via w+ mode

# %%
with open("/content/drive/My Drive/Colab Notebooks/nonexisting.txt", "r+") as file:
  file.write(". This text is added via r+")
  file.seek(0)
  print(file.read())
# Out:
# . This text is added via r+ mode
