# %%
class Auto():
    def __init__(self, color, model, make, engine):
        self.color = color
        self.model = model
        self.make = make
        self.engine = engine
  
    def run(self):
       print(f"{self.color} car is running")

    def stop(self):
       print(f"{self.color} car is stopped")

# %%
# Object creation
car1 = Auto("white", "2020", "Suzuki", "1000") # constructor/ initializer
car2 = Auto("silver", "2019", "Honda", "1300")
car3 = Auto("black", "2018", "Toyota", "1299")

# %%
car1.run()
car1.stop()
car3.run()
car3.stop()
Auto.run(car1)
# Out:
# white car is running
# white car is stopped
# black car is running
# black car is stopped
# white car is running

# %%
car1.color
# Out:
# 'white'

# %%
car1.stop()
# Out:
# white car is stopped

# %%
# Attributes or properties   >>> Variables
# behaviour / actions       >>> functions
# class                    >>> subclassing

'''
# attributes
        # color
        # make
        # model
        # engine

    color = 'black'
    make = '2020'
    model = 'Cultus'
    engine = 1000cc     


    # behaviours
              # run
              # stop
'''

# %% [markdown]
# Week 11, Youtube review session

# %%
class Car():
    def __init__(self, make, model, year, engine):
        self.make = make
        self.model = model
        self.year = year
        self.engine = engine
        self.odometer_reading = 0   
  
    def get_descriptive_name(self):
        long_name = self.make + self.model + self.engine + " " + str(self.year) 
        return long_name.title()

    def read_odometer(self):
        print("This car has " + str(self.odometer_reading) + " miles on it!")

# %%
my_new_car = Car("honda ", "City 1.3", 2020 , " 1300cc" )
print(my_new_car.get_descriptive_name())

# %%
my_new_car.read_odometer()

# %%
#Modifying Attribute Value

my_old_car = Car("Suzuki", "Cultus", 2010, "1000cc")

# %%
my_old_car.read_odometer()

# %%
my_new_car.odometer_reading =100

# %%
my_new_car.read_odometer()

# %%
my_old_car.read_odometer()

# %%
class Car():
    def __init__(self, make, model, year, engine):
        self.make = make
        self.model = model
        self.year = year
        self.engine = engine
        self.odometer_reading = 0   
  
    def get_descriptive_name(self):
        long_name = self.make + self.model + self.engine + " " + str(self.year) 
        return long_name.title()
    def set_odometer_reading(self, new_reading):
        self.odometer_reading = new_reading

    def get_odometer_reading(self):
        print("This car has " + str(self.odometer_reading) + " miles on it!") 
    def increment_odometer_reading(self, new_user_reading):
        self.odometer_reading +=new_user_reading

# %%
my_new_car = Car("honda ", "City 1.3", 2020 , " 1300cc" )
print(my_new_car.get_descriptive_name())
# Out:
# Honda City 1.3 1300Cc 2020

# %%
my_new_car.get_odometer_reading()
# Out:
# This car has 0 miles on it!

# %%
#Modifying Attribute Value

my_old_car = Car("Suzuki", "Cultus", 2010, "1000cc")

# %%
my_old_car.get_odometer_reading()
# Out:
# This car has 0 miles on it!

# %%
my_new_car.odometer_reading =100

# %%
my_new_car.get_odometer_reading()
# Out:
# This car has 100 miles on it!

# %%
my_old_car.get_odometer_reading()
# Out:
# This car has 0 miles on it!

# %%
my_new_car.set_odometer_reading(300)

# %%
my_new_car.get_odometer_reading()
# Out:
# This car has 300 miles on it!

# %%
my_new_car.set_odometer_reading(1000)

# %%
my_new_car.get_odometer_reading()
# Out:
# This car has 1000 miles on it!

# %%
my_old_car.get_odometer_reading()
# Out:
# This car has 0 miles on it!

# %%
my_old_car.set_odometer_reading(500)

# %%
my_old_car.get_odometer_reading()
# Out:
# This car has 500 miles on it!

# %%
my_new_car.increment_odometer_reading()

# %%
my_old_car.increment_odometer_reading(1000)

# %%
my_old_car.get_odometer_reading()
# Out:
# This car has 1000 miles on it!

# %%
my_old_car.increment_odometer_reading(500)

# %%
my_old_car.get_odometer_reading()
# Out:
# This car has 1500 miles on it!

# %% [markdown]
# Exercise 12
#
# I've coded a dictionary containing three lists. And I've assigned a variable, index_number, a value of 0.
# Loop through the third list looking for the element False. When the loop gets to the element you're looking for, display the current value of index_number, which will be the element's index number.
# Before the loop gets to that element, when the element being checked isn't False, increment index_number. This will be the index number of the next element to be checked in the list.
# Click the Run button    above your code. If you've coded correctly, 1 will display in the right-hand panel.

# %%
dict = {
  "list_0": [3, 1, 6],
  "list_1": ["apples", "pears", "oranges"],
  "list_2": [True, False, True],
}
index_number = 0
for a_item in dict["list_2"]:
  if a_item == False:
    print(index_number)
  else:
    index_number += 1
# Out:
# 1

# %% [markdown]
# Chapter 54, Excercise 11
#
# We're not ready to live-code a class definition yet, so let's review earlier material: Slice consecutive elements out of this list to create a new list, female_friends. The elements of the new list will be "Rachel", "Monica", and "Phoebe".
#
# Display the new list.
#
# Click the Run button    above your code. If you've coded correctly, the new list with the three female names will display in the right-hand panel.

# %%
friends = ["Ross", "Rachel", "Monica", "Phoebe", "Joey", "Chandler"]
female_friends = friends[1:4]
print(female_friends)
# Out:
# ['Rachel', 'Monica', 'Phoebe']

# %% [markdown]
# Exercise 12
#
# Pop "Gunther" off the list and assign it to a variable.
# Display the variable.
# Click the Run button    above your code. If you've coded correctly, the Gunther will display in the right-hand panel.

# %%
friends = ["Ross", "Rachel", "Monica", "Phoebe", "Gunther", "Joey", "Chandler"]
a = friends.pop(4)
print(a)
# Out:
# Gunther

# %% [markdown]
# Chapter 55, Exercise 11
#
# We're still reviewing previous chapters. In a single line of code, target "Sattermyer" in the dictionary and display it.
# Click the Run button    above your code. If you've coded correctly, Sattermyer will display in the right-hand panel.

# %%
customers = {
   0: {
        "first name":"John",
        "last name": "Ogden",
        "address": "301 Arbor Rd.",
   },
   1: {
       "first name":"Ann",
       "last name": "Sattermyer",
       "address": "PO Box 1145",
   },
   2: {
     "first name":"Jill",
     "last name": "Somers",
     "address": "3 Main St.",
   },
}

print(customers[1]["last name"])
# Out:
# Sattermyer

# %% [markdown]
# Chapter 55, Exercise 12
#
# Delete the first inner dictionary.
# Change Jill Somers' last name to Barns
# Display the customers dictionary.
# Click the Run button    above your code. If you've coded correctly, the customer dictionary, with two inner dictionaries and a changed last name for Jill Somers, will display in the right-hand panel.

# %%
customers = {
   0: {
        "first name":"John",
        "last name": "Ogden",
        "address": "301 Arbor Rd.",
   },
   1: {
       "first name":"Ann",
       "last name": "Sattermyer",
       "address": "PO Box 1145",
   },
   2: {
     "first name":"Jill",
     "last name": "Somers",
     "address": "3 Main St.",
   },
}

del customers[0]
customers[2]["last name"] = "Barns"
print(customers)
# Out:
# {1: {'first name': 'Ann', 'last name': 'Sattermyer', 'address': 'PO Box 1145'}, 2: {'first name': 'Jill', 'last name': 'Barns', 'address': '3 Main St.'}}

# %% [markdown]
# Exercise 11 CH 56
#
# Code an instance of the class.
# Display the instance.
# Click the Run button    above your code. If you've coded correctly, something like <__main__.Product object at 0x7f2fd2bac470> will display in the right-hand panel.

# %%
class Product():
  def __init__(self, color):
    self.color = color
    
faaiz = Product("anum")
print(faaiz)

# %% [markdown]
# Exercise 12 CH56
#
# Code a class.
# Code an instance of the class.
# Display the instance.
# Click the Run button    above your code. If you've coded correctly, something like <__main__.Product object at 0x7f2fd2bac470> will display in the right-hand panel.

# %%
class Fridge():
  def __init__(self, cool):
    self.cool = cool

samsung = Fridge("best")    
print(samsung)

# %% [markdown]
# Exercise 11 ch 57
#
# Code a class that has two attributes
# Display the class.
# Click the Run button    above your code. If you've coded correctly, <\class '__main__.Performer'> with the name of your class instead of Performer will display in the right-hand panel

# %%
class Student():
  def __init__(self, boys, girls):
    self.boys = boys
    self.girls = girls
    
print(Student)
# Out:
# <class '__main__.Student'>

# %% [markdown]
# Excercise 12 Ch 57
#
# Code a class with two attributes
# Code two instances of the class
# Display the first instance.
# Display the second instance.
# Click the Run button    above your code. If you've coded correctly, something like <__main__.Performer object at 0x7ff626bd6588><__main__.Performer object at 0x7ff626bd6710> will display in the right-hand panel. But it will be your class name instead of Performer.

# %%
class Student():
  def __init__(self, boys, girls):
    self.boys = boys
    self.girls = girls
    
faaiz = Student("anum", "sara")
zahid = Student("lucky", "boy")

print(faaiz)
print(zahid)

# %%
class Student():
  def __init__(self, age):
    self.age = age
id4044 = Student(19)
print(id4044.age)
# Out:
# 19

# %% [markdown]
# Exercise 10 CH 58
#
# Code a class that has just one attribute, an integer. Code an instance of the class. Then display the value of the instance's attribute. Make everything up.

# %%
class Student():
  def __init__(self, age):
    self.age = age
id4044 = Student(19)
print(id4044.age)
# Out:
# 19

# %%
class Dist():
  def __init__(self, spices):
    self.spices = spices

abc = Dist(78)
print(abc.spices)
# Out:
# 78

# %% [markdown]
# Exercise 11 CH 58
#
# Code an instance of this class.
# Display the value of one of its attributes.
# Click the Run button    above your code. If you've coded correctly, the value will display in the right-hand panel.

# %%
class Student():
  def __init__(self, age, gender, major):
    self.age = age
    self.gender = gender
    self.major = major
id90 = Student(20,"f", "computer science")
print(id90.major)
# Out:
# computer science

# %%
class Student():
  def __init__(self, age, gender, major):
    self.age = age
    self.gender = gender
    self.major = major

ab = Student(45,"f","compu" )
print(ab.age)
# Out:
# 45

# %% [markdown]
# Exercise 12 CH 58
#
# Code a class that has three attributes.
# Code an instance of the class.
# Display the value of one of its attributes.
# Click the Run button    above your code. If you've coded correctly, the value will display in the right-hand panel.

# %%
class College():
  def __init__(self, boy, girl, kid):
    self.boy = boy
    self.girl = girl
    self.kid = kid

ab = College(66, 77, 88)

print(ab.boy)
# Out:
# 66

# %% [markdown]
# Exercise 11 CH 59
#
# Call the freestanding function say_if_minor. Provide the name of the instance and the attribute name as the argument.
#
#
# Click the Run button    above your code. If you've coded correctly, This patient is a minor will display in the right-hand panel.

# %%
class Student():
  def __init__(self, age, gender, major):
    self.age = age
    self.gender = gender
    self.major = major
id90 = Student(20,"f", "computer science")
def say_if_minor(patient_age):
  if patient_age < 21:
    print("This patient is a minor")
    
say_if_minor(id90.age)
# Out:
# This patient is a minor

# %% [markdown]
# Exercise 12, CH 59
#
# Call the method say_if_minor for the instance.
#
#
# Click the Run button    above your code. If you've coded correctly, This patient is a minor will display in the right-hand panel.

# %%
class Student():
  def __init__(self, age, gender, major):
    self.age = age
    self.gender = gender
    self.major = major
  def say_if_minor(self):
    if self.age < 21:
      print("This patient is a minor")    
id90 = Student(20,"f", "computer science")


id90.say_if_minor()
# Out:
# This patient is a minor

# %% [markdown]
# Exercise 11 CH 60
#
# Code a class with one attribute and one method.
#
# The method displays the attribute.
#
# Code an instance of the class.
#
# Call the method.
#
# Click the Run button    above your code. If you've coded correctly, the value of the attribute will display in the right-hand panel.

# %%
class Student():
  def __init__(self, major):
    self.major = major
  def faaiz(self):
    print(self.major)

ab = Student("hello")
ab.faaiz()
# Out:
# hello

# %%
class Student():
  def __init__(self, girl):
    self.girl = girl
  def faaiz(self):
    print(self.girl)
ab = Student("hello")
ab.faaiz()
# Out:
# hello

# %% [markdown]
# Exercise 12
#
# Code a class with two attributes and one method.
#
# The attributes are integers.
#
# The method compares the first value with the second value. If the first value is greater than the second value, display a message.
# Code an instance of the class.
#
# Make the value of the first attribute greater than the value of the second attribute.
# Call the method.
#
# Click the Run button    above your code. If you've coded correctly, the message will display in the right-hand panel.

# %%
class College(): 
  def __init__(self, boy, girl):
    self.boy = boy
    self.girl = girl
  def faaiz(self): # THIS IS A METHOD
    if self.boy > self.girl:
      print("He is a boy")
      
anum = College(100, 59) # THIS IS A INSTANCE OF CLASS
  
anum.faaiz()  # THIS IS A METHOD CALLING
# Out:
# He is a boy

# %%
class Company():
  def __init__(self, executives, workers):
    self.executives = executives
    self.workers = workers
  def compare(self):
    if self.executives > self.workers:
      print("Uh-oh")    
ajax = Company(100, 3)
ajax.compare()
# Out:
# Uh-oh

# %%
This is the first line of a method. Fill in the blank.
  def calc(____):   # self

# %%
Exercise 2

This is the first line of a method. Fill in the blank.
  def say_if_minor________ # (self):

# %%
Code the first line of a method. Its name is whatever.
def whatever(self):

# %%
Code the first line of a method. Its name is x. Start by indenting.
  def x(self):

# %%
Exercise 5

Code the first line of a method. Make up the name of the method. Indent.
  def calc(self):

# %%
Code the second line of a method. Display the name attribute of the instance. Indent two tabs.
    print(self.name)

# %%
Code the first two lines of a method. It displays an attribute of the instance. Make up the name of the method and the name of the attribute. Indent the first line. Indent the second line two tabs.
  def show(self):
    print(self.price)

# %%
Exercise 8

Code a method. If the age attribute of the instance equals the height attribute of the instance, display a message. Make up what you need to. Indent correctly, starting with the first line.
  def compare(self):
    if self.age == self.height:
      print("Old adult!")

# %%
Exercise 9

Code a method. Concatenate two attributes and assign the combination to a variable. Make everything up. Begin by indenting.
  def combine(self):
    combination = self.first + self.last

# %%
Exercise 10

Code the first four lines of a class definition. It has one attribute. The fourth line—and the last one that you're going to code—is the first line of a method. Make everything up. Indent correctly.
class Customer():
  def __init__(self, age):
    self.age = age
  def check_age(self):

# %%
Ch 61, Ex1
Change the last_name attribute of cust_20 to "Elb"
cust_20.last_name = "Elb"

# %%
Change the population attribute of hexton to 123.
hexton.population = 123

# %%
Change the last_name attribute of no444 to the value represented by new_last.
no444.last_name = new_last

# %%
For the instance city33, call the method update, passing the argument 100.
city33.update(100)

# %%
Assign a new value, a string, to an attribute of an instance. Make everything up.
faaiz.anum = "erum"

# %%
Add together two of an instance's attributes and assign the result to a third attribute of the instance. Make everything up.
building15.total_area = building15.heated_area + building15.unheated_area

# %%
Change the value of an attribute to a Boolean. Your choice of Boolean. Make up the name of the instance and the attribute name.
faaiz.anum = True

# %%
Change the value of an attribute to the result returned by a function. The function has no arguments. Make everything up.
abc.faaiz = xyz()
OR
screen7.now_playing = select_film()

# %%
Change the value of an attribute to the result returned by a method. Both the attribute and the method are in the same class. The method has no arguments. Make everything up.
house.anum = house.erum()
or
factory20.output = factory20.double_output()

# %%
Code a class that has one attribute and one method. 
The method has one parameter. The method changes the attribute to the sum of itself plus the parameter. 
Use shorthand for this (+=). Make everything up.

class Student():
  def __init__(self, age):
    self.age = age
  def faaiz(self,death):
    self.age += death


class Building():
  def __init__(self, area):
    self.area = area
  def add(self, additional_area):
    self.area += additional_area

# %%
Ch61, excercise 12
#Code a single line that projects barstow's population based on its growth rate.
#Click the Run button    above your code. If you've coded correctly, 52500.0 will display in the right-hand panel. 

class City():
  def __init__(self, population, growth_percentage):
    self.population = population
    self.growth_percentage = growth_percentage
  def project_population(self):
    additional_population = self.population * self.growth_percentage
    projected_population = self.population + additional_population
    print(projected_population)
barstow = City(50000, .05)

barstow.project_population()
# Out:
# 52500.0

# %%
#Exercise 12, Ch 61

#Change barstow's growth percentage to .07
#Project Barstow's population based on the revised growth rate.
#Click the Run button    above your code. If you've coded correctly, 53500.0 will display in the right-hand panel.



class City():
  def __init__(self, population, growth_percentage):
    self.population = population
    self.growth_percentage = growth_percentage
  def project_population(self):
    additional_population = self.population * self.growth_percentage
    projected_population = self.population + additional_population
    print(projected_population)
barstow = City(50000, .05)

barstow.growth_percentage = .07

barstow.project_population()
# Out:
# 53500.0
