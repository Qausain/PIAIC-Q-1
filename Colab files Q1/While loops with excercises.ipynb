# %% [markdown]
# # **While Loops**

# %%
a = 0
while a <=10:
  print(a,"This is while loop printing")
  a +=1
# Out:
# 0 This is while loop printing
# 1 This is while loop printing
# 2 This is while loop printing
# 3 This is while loop printing
# 4 This is while loop printing
# 5 This is while loop printing
# 6 This is while loop printing
# 7 This is while loop printing
# 8 This is while loop printing
# 9 This is while loop printing
# 10 This is while loop printing

# %%
for num in range(11):
  print(num," THis is for loop printing")
# Out:
# 0  THis is for loop printing
# 1  THis is for loop printing
# 2  THis is for loop printing
# 3  THis is for loop printing
# 4  THis is for loop printing
# 5  THis is for loop printing
# 6  THis is for loop printing
# 7  THis is for loop printing
# 8  THis is for loop printing
# 9  THis is for loop printing
# 10  THis is for loop printing

# %%
a = 0
while a < 10:
  user_input = input("Enter your favourate food")
  a +=1
# Out:
# Enter your favourate foodQ
# Enter your favourate foodQ
# Enter your favourate foodfd
# Enter your favourate foodd
# Enter your favourate foodd
# Enter your favourate foodff
# Enter your favourate food
# Enter your favourate foodf
# Enter your favourate foodf
# Enter your favourate food

# %% [markdown]
# # **Setting a flag**

# %%
flag = True
fav_foods = []
while flag:
  user_input = input("Enter your choice  ")
  if user_input == "Q":
    flag = False

  else:
    fav_foods.append(user_input)
fav_foods
# Out:
# Enter your choice  Q
# []

# %% [markdown]
# # **SMART WAY TO LEARN PYTHON CHAPTER 51 EXCERCISES**

# %% [markdown]
# Exercise 5
#
# As long as x doesn't equal 99, display x, then increment it by 1 using the concise way to increment.

# %%
while x != 99:
  print(x)
  x += 1

# %% [markdown]
# Exercise 6
#
# As long a one integer variable is less than another integer variable, increment the first variable by 3 using the concise way to increment. Make up the variable names.

# %%
'''
while x < y:
  x += 3
'''

# %% [markdown]
# Exercise 7
#
# Code a function that has two parameters that are lists. As long as the first list is shorter than the second list, append an element, "empty", to the first list. Make up the names of the function and variables.

# %%
def abc(list, list_2):
  while len(list) < len(list_2):
  list.append("empty")

# %% [markdown]
# def even_out(first_list, second_list):
#   while len(first_list) < len(second_list):
#     first_list.append("empty")

# %% [markdown]
# Exercise 8
#
# Code a function with three parameters that hold integers passed to them by the calling code. As long as the total of the first two variables is greater than the third variable, subtract half of the third variable from the first variable using the concise way to subtract. Make everything up.

# %%
def reduce(x, y, z):
  while x + y > z:
    x -= z / 2

# %% [markdown]
# Exercise 9
#
# Code a function that asks for the user's input. Keep asking until the user enters "You're right" Make up the name of the function, the text that prompts the user, and the variable that holds the user's input. Remember to declare the variable as an empty string in line 2.

# %%
def get_validation():
  response = ""
  while response != "I am fine":
    response = input("How are You: ")
get_validation()
# Out:
# How are You: df
# How are You: fd
# How are You: I am fine

# %%
def abc():
  g = ""
  while g != "You are right":
    g = input("Tell me that I am right")    


abc()

# %%
Exercise 10

As long as a variable holding an integer is less than the value of another variable, 
run a for loop that loops through all the elements of a list and adds each element of the list to the first variable. 
Use the concise approach to increment the first variable. Make everything up.

# %%
while first_number < second_number:
  for number in number_list:
    first_number += number

# %% [markdown]
# Exercise 11
#
# Code a while loop. As long as x is less than or equal to 10, display x then add 2 to it.
# Click the Run button    above your code. If you've coded correctly, a column of numbers 0 2 4 6 8 10 will display in the right-hand panel. (You can click Instructions at the top of the right-hand panel to see the correct code.)

# %%
x = 0
while x <= 10:
  print(x)
  x += 2
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# Exercise 12
#
# As long as the counter is less than the length of list_of_names, append an element of list_of_names to second_list_of_names. Then increment the counter. (Use the counter as the index of each element as you loop through list_of_names.)
# Display second_list_of_names.
# Click the Run button    above your code. If you've coded correctly, second_list_of_names, identical to list_of_names, will display in the right-hand panel.

# %%
list_of_names = ["Farina", "Madi", "Annie", "Max", "Vlad", "Punya", "Muhammad"]
second_list_of_names = []
counter = 0
while counter < len(list_of_names):
  second_list_of_names.append(list_of_names[counter])
  counter += 1

print(second_list_of_names)
# Out:
# ['Farina', 'Madi', 'Annie', 'Max', 'Vlad', 'Punya', 'Muhammad']

# %% [markdown]
# CHAPTER 52, Exercise 11
#
# Assign different Booleans to two variables.
# Assign 0 to a third variable.
# As long as the two Boolean variables have different values, increment the third variable by 1 and make the first Boolean variable equal to the second Boolean variable.
# Display the third variable.
# Click the Run button    above your code. If you've coded correctly, 1 will display in the right-hand panel.

# %%
a = True
b = False
c = 0
while a != b:
  c += 1
  a = b
  
print(c)
# Out:
# 1

# %% [markdown]
# Loop through the dictionary. When a value is True, display its key.
# Click the Run button    above your code. If you've coded correctly, all the keys except 100 will display in the right-hand panel. Because of a Python technicality, they won't be in order.

# %%
dict = {1: True, 4: True, 10: True, 100: False, 200: True}
for an_item in dict:
  if dict[an_item]== True:
    print(dict[an_item])
# Out:
# True
# True
# True
# True

# %%
dict = {1: True, 4: True, 10: True, 100: False, 200: True}
for key, value in dict.items():
  if value == True:
    print(key)
# Out:
# 1
# 4
# 10
# 200
