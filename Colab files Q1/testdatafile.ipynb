# %%
with open("newdatafile.txt", "r") as f:
	content = f.read()
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-196aad4a641c> in <module>()
# ----> 1 with open("newdatafile.txt", "r") as f:
#       2         content = f.read()
#       3 print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'newdatafile.txt'
