# %% [markdown]
# # **LAMBDA FUNCTION**

# %% [markdown]
# 1 LINE function
#
# 2 Anonimous Function
#
# 3 Never use before and after

# %%
abc = lambda x1, x2, x3: x1 + x2+ x3

abc(1,3,5)
# Out:
# 9

# %% [markdown]
# never use before and after

# %%
ab1 = {"boy": 5, "male": 10, "girl": 15}

{k:v for k,v in sorted(ab1.items(), key=lambda x:x[1])}


# x = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0} {k: v for k, v in sorted(x.items(), key=lambda item: item[1])}
# Out:
# {'boy': 5, 'girl': 15, 'male': 10}
