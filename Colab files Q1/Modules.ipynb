# %% [markdown]
# # **MODULES**

# %%
print('hello')
# Out:
# hello

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
cd
# Out:
# <function dir>

# %%
import calc1 as c

c.add(34, 45)
# Out:
# 79

# %%
c.div(100, 50)
# Out:
# 2.0

# %%
c.mul(6800, 8)
# Out:
# 54400

# %%
c.sub(74000, 50000)
# Out:
# 24000

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
# %load calc1.py
