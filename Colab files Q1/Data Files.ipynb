# %% [markdown]
# Exercise 1
#
# Fill in the blank.
# ____ open("whatever.txt", "w") as file_to_work_with: Ans = with

# %% [markdown]
# Exercise 2
#
# When you open a file by writing with at the beginning of the line, Python _______ the file automatically after you write to it.
#
# Ans: closes

# %% [markdown]
# Exercise 3
#
# In the orange box type the next character. I'll autocomplete. Don't type spaces or carriage returns.
# Fill in the blank.
# _____________("whatever.txt", "w") as
# Ans: with open

# %% [markdown]
# Exercise 4
#
# Fail-safe coding. If you type the wrong character, I'll cancel the keystroke. Type spaces. When the exercise is complete, I'll turn the exercise number green.
# The name of the file is "names.txt". Fill in the blank.
# ____________________________, "w") as f:
# Ans: with open("names.txt"

# %% [markdown]
# with open("names.txt"

# %% [markdown]
# Exercise 5
#
# What is the file handle here?
# with open("cities.txt", "w") as data:
#
# Ans: Data

# %% [markdown]
# Exercise 6
#
# Open the file "x.txt" so you can write to it. Make up the file handle.
# Ans: with open("x.txt", "w") as the_file_to_write_to:

# %% [markdown]
# Exercise 7
#
# Open a file so you can write to it. Make up the file name and file handle.
#
# with open("recipes.txt", "w") as f:
# with open("classes.txt", "w") as the_file_to_write_to:

# %% [markdown]
# Exercise 8
#
# If the Python program that opens a file is in the folder named python, the text file is in the folder named _______, according to this code.
# with open("recipes.txt", "w") as f:
# Ans: python

# %% [markdown]
# Exercise 9
#
# Open a text file that's in a different folder than the Python program that's opening it. Assume you're in Windows. Make everything up.
#
#
# 1)with open("text_files\recipes.txt", "w") as f:
# 2)with open("faaiz\anum.txt", "w") as f:

# %% [markdown]
# Exercise 10
#
# Open a text file that's in a different folder than the Python program that's opening it. Assume you're in OS X or Linux. Make everything up.
#
# with open("text_files/recipes.txt", "w") as f:

# %%
with open("newfile.txt",)
  content = file.read()
print(content)
# Out:
#   File "<ipython-input-4-690f298a3b89>", line 1
#     with open("https:\\drive.google.com\drive\u\0\folders\1ahqGC2dFfgdSCzHgjQv26t09paZz09Ai/newdatafile.txt", "r") as file:
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 30-31: truncated \uXXXX escape

# %%
print("hello")
# Out:
# hello
