# %%
userinput = int(input("Enter Some thing"))
type(userinput)
# Out:
# Enter Some thing45
# int

# %%
float(6)
# Out:
# 6.0

# %%
a = "qauSain manZoor"
a.upper()
# Out:
# 'QAUSAIN MANZOOR'

# %%
a.title()
# Out:
# 'Qausain Manzoor'

# %%
a.lower()
# Out:
# 'qausain manzoor'

# %%
# Exercise 12
'''
Get the user's age.
Python interprets the user's input as a string even if it's a number, so convert the response to an integer.
Add 1 to the integer.
Convert the sum to a string.
Display Next year you'll be plus next year's age.
'''
age = input("Enter your real age: ")
a = int(age)
b = a + 1
c = str(b)
print("Next year you will be " + c)
# Out:
# Enter your real age: 45
# Next year you will be 46

# %%
print("Hello\n")
